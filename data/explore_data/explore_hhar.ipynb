# %%
import torch
import torch.nn as nn

# Dropout với xác suất 0.5 (tắt 50% neuron)
dropout = nn.Dropout(p=0.5)

x = torch.randn(10)
print("Input:", x)
print("Output:", dropout(x))
# Out:
# Input: tensor([ 1.6081,  0.8926,  0.4844, -0.5326, -1.7418,  1.3977,  0.0515,  0.0640,
#         -1.0296,  1.1515])
# Output: tensor([ 3.2163,  0.0000,  0.0000, -0.0000, -0.0000,  0.0000,  0.1031,  0.1280,
#         -2.0592,  2.3030])
